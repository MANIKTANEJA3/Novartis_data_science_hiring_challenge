# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d54960f3-6ffc-4d74-9aa7-0b35ef2b41a9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d54960f3-6ffc-4d74-9aa7-0b35ef2b41a9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Train.csv to Train.csv

# %%
import pandas as pd
df = pd.read_csv("Train.csv")
df.shape
# Out:
# (23856, 18)

# %%
df.head()
# Out:
#   INCIDENT_ID       DATE  X_1  X_2  ...  X_13  X_14  X_15  MULTIPLE_OFFENSE
# 0   CR_102659  04-JUL-04    0   36  ...    92    29    36                 0
# 1   CR_189752  18-JUL-17    1   37  ...   103   142    34                 1
# 2   CR_184637  15-MAR-17    0    3  ...   110    93    34                 1
# 3   CR_139071  13-FEB-09    0   33  ...    72    29    34                 1
# 4   CR_109335  13-APR-05    0   33  ...   112    29    43                 1
#
# [5 rows x 18 columns]

# %%
df.tail()
# Out:
#       INCIDENT_ID       DATE  X_1  X_2  ...  X_13  X_14  X_15  MULTIPLE_OFFENSE
# 23851    CR_88991  11-JAN-02    1   47  ...    98    29    34                 1
# 23852    CR_46369  05-FEB-97    0   33  ...   112    29    43                 1
# 23853   CR_157556  03-APR-12    0   25  ...    10    29    18                 1
# 23854   CR_103180  25-JAN-04    0   39  ...   112   103    43                 1
# 23855    CR_22575  08-NOV-94    7   36  ...    92    29    34                 1
#
# [5 rows x 18 columns]

# %%
total_rows_df = df.count
print(total_rows_df)
# Out:
# <bound method DataFrame.count of       INCIDENT_ID       DATE  X_1  X_2  ...  X_13  X_14  X_15  MULTIPLE_OFFENSE
# 0       CR_102659  04-JUL-04    0   36  ...    92    29    36                 0
# 1       CR_189752  18-JUL-17    1   37  ...   103   142    34                 1
# 2       CR_184637  15-MAR-17    0    3  ...   110    93    34                 1
# 3       CR_139071  13-FEB-09    0   33  ...    72    29    34                 1
# 4       CR_109335  13-APR-05    0   33  ...   112    29    43                 1
# ...           ...        ...  ...  ...  ...   ...   ...   ...               ...
# 23851    CR_88991  11-JAN-02    1   47  ...    98    29    34                 1
# 23852    CR_46369  05-FEB-97    0   33  ...   112    29    43                 1
# 23853   CR_157556  03-APR-12    0   25  ...    10    29    18                 1
# 23854   CR_103180  25-JAN-04    0   39  ...   112   103    43                 1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23856 entries, 0 to 23855
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   INCIDENT_ID       23856 non-null  object
#  1   DATE              23856 non-null  object
#  2   X_1               23856 non-null  int64
#  3   X_2               23856 non-null  int64
#  4   X_3               23856 non-null  int64
#  5   X_4               23856 non-null  int64
#  6   X_5               23856 non-null  int64
#  7   X_6               23856 non-null  int64
#  8   X_7               23856 non-null  int64
#  9   X_8               23856 non-null  int64
#  10  X_9               23856 non-null  int64
#  11  X_10              23856 non-null  int64
#  12  X_11              23856 non-null  int64
#  13  X_12              23674 non-null  float64
#  14  X_13              23856 non-null  int64
#  15  X_14              23856 non-null  int64
# ...

# %%
df.describe()
# Out:
#                 X_1           X_2  ...          X_15  MULTIPLE_OFFENSE
# count  23856.000000  23856.000000  ...  23856.000000      23856.000000
# mean       0.483778     24.791206  ...     33.464747          0.955231
# std        1.439738     15.240231  ...      8.386834          0.206800
# min        0.000000      0.000000  ...      0.000000          0.000000
# 25%        0.000000      7.000000  ...     34.000000          1.000000
# 50%        0.000000     24.000000  ...     34.000000          1.000000
# 75%        0.000000     36.000000  ...     34.000000          1.000000
# max        7.000000     52.000000  ...     50.000000          1.000000
#
# [8 rows x 16 columns]

# %%
df.isnull().sum()
# Out:
# INCIDENT_ID           0
# DATE                  0
# X_1                   0
# X_2                   0
# X_3                   0
# X_4                   0
# X_5                   0
# X_6                   0
# X_7                   0
# X_8                   0
# X_9                   0
# X_10                  0
# X_11                  0
# X_12                182
# X_13                  0
# X_14                  0
# X_15                  0
# MULTIPLE_OFFENSE      0
# dtype: int64

# %%
total_rows_df = df.count
print(total_rows_df)
# Out:
# <bound method DataFrame.count of       INCIDENT_ID       DATE  X_1  X_2  ...  X_13  X_14  X_15  MULTIPLE_OFFENSE
# 0       CR_102659  04-JUL-04    0   36  ...    92    29    36                 0
# 1       CR_189752  18-JUL-17    1   37  ...   103   142    34                 1
# 2       CR_184637  15-MAR-17    0    3  ...   110    93    34                 1
# 3       CR_139071  13-FEB-09    0   33  ...    72    29    34                 1
# 4       CR_109335  13-APR-05    0   33  ...   112    29    43                 1
# ...           ...        ...  ...  ...  ...   ...   ...   ...               ...
# 23851    CR_88991  11-JAN-02    1   47  ...    98    29    34                 1
# 23852    CR_46369  05-FEB-97    0   33  ...   112    29    43                 1
# 23853   CR_157556  03-APR-12    0   25  ...    10    29    18                 1
# 23854   CR_103180  25-JAN-04    0   39  ...   112   103    43                 1
# ...

# %%
df1 = df.drop(['DATE'],axis = 1)

# %%
df1.head()  # without the date column
# Out:
#   INCIDENT_ID  X_1  X_2  X_3  X_4  ...  X_12  X_13  X_14  X_15  MULTIPLE_OFFENSE
# 0   CR_102659    0   36   34    2  ...   1.0    92    29    36                 0
# 1   CR_189752    1   37   37    0  ...   1.0   103   142    34                 1
# 2   CR_184637    0    3    2    3  ...   1.0   110    93    34                 1
# 3   CR_139071    0   33   32    2  ...   1.0    72    29    34                 1
# 4   CR_109335    0   33   32    2  ...   0.0   112    29    43                 1
#
# [5 rows x 17 columns]

# %%
total_rows_df1 = df1.count
print(total_rows_df1)
# Out:
# <bound method DataFrame.count of       INCIDENT_ID  X_1  X_2  X_3  X_4  ...  X_12  X_13  X_14  X_15  MULTIPLE_OFFENSE
# 0       CR_102659    0   36   34    2  ...   1.0    92    29    36                 0
# 1       CR_189752    1   37   37    0  ...   1.0   103   142    34                 1
# 2       CR_184637    0    3    2    3  ...   1.0   110    93    34                 1
# 3       CR_139071    0   33   32    2  ...   1.0    72    29    34                 1
# 4       CR_109335    0   33   32    2  ...   0.0   112    29    43                 1
# ...           ...  ...  ...  ...  ...  ...   ...   ...   ...   ...               ...
# 23851    CR_88991    1   47   48    7  ...   0.0    98    29    34                 1
# 23852    CR_46369    0   33   32    2  ...   0.0   112    29    43                 1
# 23853   CR_157556    0   25   25    9  ...   0.0    10    29    18                 1
# 23854   CR_103180    0   39   39    6  ...   0.0   112   103    43                 1
# ...

# %%
df2 = df1.drop(['INCIDENT_ID'],axis=1)

# %%
total_rows_df2 = df2.count
print(total_rows_df2)
# Out:
# <bound method DataFrame.count of        X_1  X_2  X_3  X_4  X_5  ...  X_12  X_13  X_14  X_15  MULTIPLE_OFFENSE
# 0        0   36   34    2    1  ...   1.0    92    29    36                 0
# 1        1   37   37    0    0  ...   1.0   103   142    34                 1
# 2        0    3    2    3    5  ...   1.0   110    93    34                 1
# 3        0   33   32    2    1  ...   1.0    72    29    34                 1
# 4        0   33   32    2    1  ...   0.0   112    29    43                 1
# ...    ...  ...  ...  ...  ...  ...   ...   ...   ...   ...               ...
# 23851    1   47   48    7    3  ...   0.0    98    29    34                 1
# 23852    0   33   32    2    1  ...   0.0   112    29    43                 1
# 23853    0   25   25    9    0  ...   0.0    10    29    18                 1
# 23854    0   39   39    6    5  ...   0.0   112   103    43                 1
# 23855    7   36   34    2    1  ...   1.0    92    29    34                 1
#
# ...

# %%
df2.head()
# Out:
#    X_1  X_2  X_3  X_4  X_5  X_6  ...  X_11  X_12  X_13  X_14  X_15  MULTIPLE_OFFENSE
# 0    0   36   34    2    1    5  ...   174   1.0    92    29    36                 0
# 1    1   37   37    0    0   11  ...   236   1.0   103   142    34                 1
# 2    0    3    2    3    5    1  ...   174   1.0   110    93    34                 1
# 3    0   33   32    2    1    7  ...   249   1.0    72    29    34                 1
# 4    0   33   32    2    1    8  ...   174   0.0   112    29    43                 1
#
# [5 rows x 16 columns]

# %%
df3 = pd.DataFrame(df2.drop(['MULTIPLE_OFFENSE'],axis=1))
df3.size
# Out:
# 357840

# %%
df3.head()
# Out:
#    X_1  X_2  X_3  X_4  X_5  X_6  X_7  ...  X_9  X_10  X_11  X_12  X_13  X_14  X_15
# 0    0   36   34    2    1    5    6  ...    6     1   174   1.0    92    29    36
# 1    1   37   37    0    0   11   17  ...    6     1   236   1.0   103   142    34
# 2    0    3    2    3    5    1    0  ...    3     1   174   1.0   110    93    34
# 3    0   33   32    2    1    7    1  ...    6     1   249   1.0    72    29    34
# 4    0   33   32    2    1    8    3  ...    5     1   174   0.0   112    29    43
#
# [5 rows x 15 columns]

# %%
total_rows_df3 = df3.count
print(total_rows_df3)
# Out:
# <bound method DataFrame.count of        X_1  X_2  X_3  X_4  X_5  X_6  ...  X_10  X_11  X_12  X_13  X_14  X_15
# 0        0   36   34    2    1    5  ...     1   174   1.0    92    29    36
# 1        1   37   37    0    0   11  ...     1   236   1.0   103   142    34
# 2        0    3    2    3    5    1  ...     1   174   1.0   110    93    34
# 3        0   33   32    2    1    7  ...     1   249   1.0    72    29    34
# 4        0   33   32    2    1    8  ...     1   174   0.0   112    29    43
# ...    ...  ...  ...  ...  ...  ...  ...   ...   ...   ...   ...   ...   ...
# 23851    1   47   48    7    3   15  ...     1   174   0.0    98    29    34
# 23852    0   33   32    2    1    5  ...     1   174   0.0   112    29    43
# 23853    0   25   25    9    0    3  ...     1   174   0.0    10    29    18
# 23854    0   39   39    6    5    2  ...     1   127   0.0   112   103    43
# 23855    7   36   34    2    1    9  ...     1   249   1.0    92    29    34
#
# ...

# %%
df3.isnull().sum() # 182 values are missing in X_12
# Out:
# X_1       0
# X_2       0
# X_3       0
# X_4       0
# X_5       0
# X_6       0
# X_7       0
# X_8       0
# X_9       0
# X_10      0
# X_11      0
# X_12    182
# X_13      0
# X_14      0
# X_15      0
# dtype: int64

# %%
df3['X_12'] = df3['X_12'].fillna((df3['X_12'].mean()))

# %%
df3['X_12'].isnull().sum() #all the values of X_12 has been filled with the mean of the entire column
# Out:
# 0

# %%
import seaborn as sns
sns.set(style="darkgrid")

sns.pairplot(df3, palette=("GnBu_d"))
import matplotlib.pyplot as plt

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
corrmat = df3.corr()
f, ax1= plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True)
plt.show()

# %%
import matplotlib.pyplot as plt
df3[df3.dtypes[(df3.dtypes=="float64")|(df3.dtypes=="int64")].index.values].hist(figsize=[11,11])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6f643b8588>,
# ...
#       dtype=object)

# %%
from sklearn.preprocessing import MinMaxScaler
min_max=MinMaxScaler()


df3_minmax=min_max.fit_transform(df3[['X_1', 'X_2','X_3', 'X_4', 'X_5','X_6','X_7','X_8','X_9','X_10','X_11','X_12','X_13','X_14','X_15']])

#the values have been scaled


scaled_features_df = pd.DataFrame(df3_minmax)

# %%
scaled_features_df.head()
# Out:
#          0         1         2    3   ...        11        12        13    14
# 0  0.000000  0.692308  0.653846  0.2  ...  0.011111  0.793103  0.204225  0.72
# 1  0.142857  0.711538  0.711538  0.0  ...  0.011111  0.887931  1.000000  0.68
# 2  0.000000  0.057692  0.038462  0.3  ...  0.011111  0.948276  0.654930  0.68
# 3  0.000000  0.634615  0.615385  0.2  ...  0.011111  0.620690  0.204225  0.68
# 4  0.000000  0.634615  0.615385  0.2  ...  0.000000  0.965517  0.204225  0.86
#
# [5 rows x 15 columns]

# %%
scaled_features_df.columns = ['X_1','X_2','X_3','X_4','X_5',	'X_6',	'X_7',	'X_8',	'X_9',	'X_10',	'X_11',	'X_12',	'X_13',	'X_14','X_15']

# %%
scaled_features_df.head()
# Out:
#         X_1       X_2       X_3  X_4  ...      X_12      X_13      X_14  X_15
# 0  0.000000  0.692308  0.653846  0.2  ...  0.011111  0.793103  0.204225  0.72
# 1  0.142857  0.711538  0.711538  0.0  ...  0.011111  0.887931  1.000000  0.68
# 2  0.000000  0.057692  0.038462  0.3  ...  0.011111  0.948276  0.654930  0.68
# 3  0.000000  0.634615  0.615385  0.2  ...  0.011111  0.620690  0.204225  0.68
# 4  0.000000  0.634615  0.615385  0.2  ...  0.000000  0.965517  0.204225  0.86
#
# [5 rows x 15 columns]

# %%
scaled_features_df[scaled_features_df.dtypes[(scaled_features_df.dtypes=="float64")|(scaled_features_df.dtypes=="int64")].index.values].hist(figsize=[11,11])
plt.show()

# %%
scaled_features_df['X_12'] = scaled_features_df['X_12'].fillna((scaled_features_df['X_12'].mean()))

# %%
scaled_features_df.isnull().sum()
# Out:
# X_1     0
# X_2     0
# X_3     0
# X_4     0
# X_5     0
# X_6     0
# X_7     0
# X_8     0
# X_9     0
# X_10    0
# X_11    0
# X_12    0
# X_13    0
# X_14    0
# X_15    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

y = df['MULTIPLE_OFFENSE']
X_train, X_test, Y_train, Y_test = train_test_split(scaled_features_df, y, test_size=0.2,random_state=42)

# %%
X_train.isnull().sum()
# Out:
# X_1     0
# X_2     0
# X_3     0
# X_4     0
# X_5     0
# X_6     0
# X_7     0
# X_8     0
# X_9     0
# X_10    0
# X_11    0
# X_12    0
# X_13    0
# X_14    0
# X_15    0
# dtype: int64

# %%
X_test.isnull().sum()
# Out:
# X_1     0
# X_2     0
# X_3     0
# X_4     0
# X_5     0
# X_6     0
# X_7     0
# X_8     0
# X_9     0
# X_10    0
# X_11    0
# X_12    0
# X_13    0
# X_14    0
# X_15    0
# dtype: int64

# %%
Y_train.isnull().sum()
# Out:
# 0

# %%
Y_test.isnull().sum()
# Out:
# 0

# %%
# knn model fit
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

knn = KNeighborsClassifier(n_neighbors=5)

knn.fit(X_train,Y_train)

accuracy_score(Y_test,knn.predict(X_test))
# Out:
# 0.9551550712489523

# %%
# logistic regression model fit
from sklearn.linear_model import LogisticRegression 
log=LogisticRegression(penalty='l2',C=.01)
log.fit(X_train,Y_train)

accuracy_score(Y_test,log.predict(X_test))
# Out:
# 0.9507544006705784

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics

clf = DecisionTreeClassifier()
clf = clf.fit(X_train,Y_train)
y_pred = clf.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9113579212070411

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(criterion='entropy',splitter='best',random_state=0)
model.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=0, splitter='best')

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators = 100 , criterion = 'entropy',random_state=0)
model.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='entropy', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                        warm_start=False)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
C_M = confusion_matrix(Y_test,y_pred)
C_M
# Out:
# array([[ 208,   27],
#        [   8, 4529]])

# %%
model.score(X_test,Y_test)
# Out:
# 0.9926655490360435

# %%
from sklearn.ensemble import AdaBoostClassifier

classifier = AdaBoostClassifier(
    DecisionTreeClassifier(max_depth=1),
    n_estimators=200
)
classifier.fit(X_train, Y_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R',
#                    base_estimator=DecisionTreeClassifier(ccp_alpha=0.0,
#                                                          class_weight=None,
#                                                          criterion='gini',
#                                                          max_depth=1,
#                                                          max_features=None,
#                                                          max_leaf_nodes=None,
#                                                          min_impurity_decrease=0.0,
#                                                          min_impurity_split=None,
#                                                          min_samples_leaf=1,
#                                                          min_samples_split=2,
#                                                          min_weight_fraction_leaf=0.0,
#                                                          presort='deprecated',
# ...

# %%
predictions = classifier.predict(X_test)

# %%
confusion_matrix(Y_test, predictions)
# Out:
# array([[ 234,    1],
#        [   1, 4536]])

# %%
model.score(X_test,Y_test)
# Out:
# 0.9926655490360435

# %%
unique_value = df["INCIDENT_ID"].nunique()
print(unique_value)
# Out:
# 23856

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-350298de-5bed-4b74-a5bb-86e2e5d139c4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-350298de-5bed-4b74-a5bb-86e2e5d139c4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving USE.csv to USE.csv

# %%
import pandas as pd
test = pd.read_csv("USE.csv")
test.shape
# Out:
# (15903, 17)

# %%
test.head()
# Out:
#   INCIDENT_ID       DATE  X_1  X_2  X_3  ...  X_11  X_12  X_13  X_14  X_15
# 0   CR_195453  01-Feb-18    0   30   35  ...   174   NaN    72   119    23
# 1   CR_103520  05-Mar-04    0   44   44  ...   316   0.0    12    29    34
# 2   CR_196089  27-Jan-18    0   34   33  ...   316   1.0    72     0    34
# 3   CR_112195  18-Aug-06    7    3    2  ...   174   1.0   112    87    34
# 4   CR_149832  31-Oct-11    0    7    8  ...   174   0.0   112    93    43
#
# [5 rows x 17 columns]

# %%
test.describe()
# Out:
#                 X_1           X_2  ...          X_14          X_15
# count  15903.000000  15903.000000  ...  15903.000000  15903.000000
# mean       0.468088     24.722631  ...     72.218575     33.422625
# std        1.412112     15.228841  ...     43.438227      8.314284
# min        0.000000      0.000000  ...      0.000000      0.000000
# 25%        0.000000      7.000000  ...     29.000000     34.000000
# 50%        0.000000     24.000000  ...     62.000000     34.000000
# 75%        0.000000     36.000000  ...    107.000000     34.000000
# max        7.000000     52.000000  ...    142.000000     50.000000
#
# [8 rows x 15 columns]

# %%
test.isnull().sum()
# Out:
# INCIDENT_ID      0
# DATE             0
# X_1              0
# X_2              0
# X_3              0
# X_4              0
# X_5              0
# X_6              0
# X_7              0
# X_8              0
# X_9              0
# X_10             0
# X_11             0
# X_12           127
# X_13             0
# X_14             0
# X_15             0
# dtype: int64

# %%
test_no_id = test.drop(['INCIDENT_ID','DATE'],axis=1)

# %%
test_no_id.head()
# Out:
#    X_1  X_2  X_3  X_4  X_5  X_6  X_7  ...  X_9  X_10  X_11  X_12  X_13  X_14  X_15
# 0    0   30   35    7    3    6    4  ...    5     1   174   NaN    72   119    23
# 1    0   44   44    1    3    7    1  ...    6     1   316   0.0    12    29    34
# 2    0   34   33    3    5    2    7  ...    0     1   316   1.0    72     0    34
# 3    7    3    2    3    5    9    8  ...    5     1   174   1.0   112    87    34
# 4    0    7    8    7    3    2    7  ...    5     1   174   0.0   112    93    43
#
# [5 rows x 15 columns]

# %%
test_no_id[test_no_id.dtypes[(test_no_id.dtypes=="float64")|(test_no_id.dtypes=="int64")].index.values].hist(figsize=[11,11])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6f6be15e80>,
# ...
#       dtype=object)

# %%
from sklearn.preprocessing import MinMaxScaler
min_max=MinMaxScaler()


test_minmax=min_max.fit_transform(test_no_id[['X_1', 'X_2','X_3', 'X_4', 'X_5','X_6','X_7','X_8','X_9','X_10','X_11','X_12','X_13','X_14','X_15']])

#the values have been scaled


test_scaled = pd.DataFrame(test_minmax)

# %%
test_scaled.head()
# Out:
#     0         1         2    3    4   ...        10     11        12        13    14
# 0  0.0  0.576923  0.673077  0.7  0.6  ...  0.524096    NaN  0.615385  0.838028  0.46
# 1  0.0  0.846154  0.846154  0.1  0.6  ...  0.951807  0.000  0.102564  0.204225  0.68
# 2  0.0  0.653846  0.634615  0.3  1.0  ...  0.951807  0.025  0.615385  0.000000  0.68
# 3  1.0  0.057692  0.038462  0.3  1.0  ...  0.524096  0.025  0.957265  0.612676  0.68
# 4  0.0  0.134615  0.153846  0.7  0.6  ...  0.524096  0.000  0.957265  0.654930  0.86
#
# [5 rows x 15 columns]

# %%
test_scaled.columns = ['X_1','X_2','X_3','X_4','X_5',	'X_6',	'X_7',	'X_8',	'X_9',	'X_10',	'X_11',	'X_12',	'X_13',	'X_14','X_15']

# %%
test_scaled.head()
# Out:
#    X_1       X_2       X_3  X_4  X_5  ...      X_11   X_12      X_13      X_14  X_15
# 0  0.0  0.576923  0.673077  0.7  0.6  ...  0.524096    NaN  0.615385  0.838028  0.46
# 1  0.0  0.846154  0.846154  0.1  0.6  ...  0.951807  0.000  0.102564  0.204225  0.68
# 2  0.0  0.653846  0.634615  0.3  1.0  ...  0.951807  0.025  0.615385  0.000000  0.68
# 3  1.0  0.057692  0.038462  0.3  1.0  ...  0.524096  0.025  0.957265  0.612676  0.68
# 4  0.0  0.134615  0.153846  0.7  0.6  ...  0.524096  0.000  0.957265  0.654930  0.86
#
# [5 rows x 15 columns]

# %%
test_scaled[test_scaled.dtypes[(test_scaled.dtypes=="float64")|(test_scaled.dtypes=="int64")].index.values].hist(figsize=[11,11])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6f6be34c88>,
# ...
#       dtype=object)

# %%
test_scaled.isnull().sum()
# Out:
# X_1       0
# X_2       0
# X_3       0
# X_4       0
# X_5       0
# X_6       0
# X_7       0
# X_8       0
# X_9       0
# X_10      0
# X_11      0
# X_12    127
# X_13      0
# X_14      0
# X_15      0
# dtype: int64

# %%
#test_scaled['X_9'] = test_scaled['X_9'].fillna((test_scaled['X_9'].mean()))
#test_scaled['X_10'] = test_scaled['X_10'].fillna((test_scaled['X_10'].mean()))
#test_scaled['X_11'] = test_scaled['X_11'].fillna((test_scaled['X_11'].mean()))
test_scaled['X_12'] = test_scaled['X_12'].fillna((test_scaled['X_12'].mean()))
#test_scaled['X_13'] = test_scaled['X_13'].fillna((test_scaled['X_13'].mean()))
#test_scaled['X_14'] = test_scaled['X_14'].fillna((test_scaled['X_14'].mean()))
#test_scaled['X_15'] = test_scaled['X_15'].fillna((test_scaled['X_15'].mean()))

# %%
test_scaled.isnull().sum()
# Out:
# X_1     0
# X_2     0
# X_3     0
# X_4     0
# X_5     0
# X_6     0
# X_7     0
# X_8     0
# X_9     0
# X_10    0
# X_11    0
# X_12    0
# X_13    0
# X_14    0
# X_15    0
# dtype: int64

# %%
test_predictions = classifier.predict(test_scaled)

# %%
Incident_id = test['INCIDENT_ID']
submission_df_2 = pd.DataFrame({
                  "INCIDENT_ID": Incident_id, 
                  "MULTIPLE_OFFENSE": test_predictions})

# %%
submission_df_2.to_csv('submission_2.csv', index=False)

# %%
test_predictions.shape
# Out:
# (15903,)

# %%
submission_df_2.shape
# Out:
# (15903, 2)
